# %% [markdown]
# # Customer Segmentation
# ## Questions to answer
# 1. Demographic relationship between customers
# 2. Geographic relationship in view of customer characteristics

# %% [markdown]
# ---
# ## <a class="anchor" id="data">I. Data Import and Wrangling</a>
#
# ### 1. Libraries

# %%
import pandas as pd
import numpy as np

from datetime import datetime as dt
from datetime import timedelta
import re
from sklearn.preprocessing import StandardScaler

import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns

from Olist_classes import Olist_analysis as oa

import plotly as py
import plotly.offline as offline
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
from plotly.graph_objs import Scatter, Figure, Layout
from plotly import tools

init_notebook_mode(connected=True)
# %matplotlib inline
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ### 2. Importing data

# %% [markdown]
# ### Customer data

# %%
# Customer lookup table
df_customer = pd.read_csv("archive/olist_customers_dataset.csv")

# %%
# Taking a peek
df_customer.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
df_customer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %% [markdown]
# This looks like a complete dataset. Doublecheck:

# %%
df_customer.isna().sum()
# Out:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %%
# Finding duplicates
df_customer.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Order data

# %%
df_orders = pd.read_csv('archive/df_orders_consolidated.csv')

# %%
df_orders.head()
# Out:
#    Unnamed: 0                          order_id  \
# 0           0  2e7a8482f6fb09756ca50c10d7bfc047
# 1           1  35d3a51724a47ef1d0b89911e39cc4ff
# 2           2  c4f710df20f7d1500da1aef81a993f65
# 3           3  81e5043198a44ddeb226002ff55d8ad4
# 4           4  03b218d39c422c250f389120c531b61f
#
#                         customer_id order_status order_purchase_timestamp  \
# 0  08c5351a6aca1c1589a38f244edeee9d      shipped      2016-09-04 21:15:19
# 1  27ab53f26192510ff85872aeb3759dcc    delivered      2016-10-04 14:23:50
# 2  4b671f05b6eb9dc1d2c1bae9c8c78536    delivered      2016-10-10 15:50:01
# 3  ddd15ef77c83eea8c534d2896173a927    delivered      2017-01-09 00:37:18
# 4  db857a86c685a6a3a02a705961ec1ff1    delivered      2017-01-14 14:20:01
#
#      order_approved_at order_delivered_carrier_date  \
# 0  2016-10-07 13:18:03          2016-10-18 13:14:51
# 1  2016-10-05 02:44:29          2016-10-14 02:44:30
# 2  2016-10-10 16:02:37          2016-10-18 15:53:51
# 3  2017-01-09 00:45:09          2017-01-09 09:10:53
# 4  2017-01-14 14:30:43          2017-01-16 09:23:45
#
#   order_delivered_customer_date order_estimated_delivery_date order_time  ...  \
# 0                           NaN                    2016-10-20   21:15:19  ...
# 1           2016-10-26 15:03:52                    2016-12-20   14:23:50  ...
# 2           2016-10-26 16:35:46                    2016-12-14   15:50:01  ...
# 3           2017-02-24 09:42:38                    2017-02-24   00:37:18  ...
# 4           2017-01-18 10:53:42                    2017-03-01   14:20:01  ...
#
#   product_category_name  product_name_lenght  product_description_lenght  \
# 0      moveis_decoracao                 59.0                       426.0
# 1      moveis_decoracao                 59.0                       426.0
# 2      moveis_decoracao                 59.0                       426.0
# 3      moveis_decoracao                 59.0                       426.0
# 4      moveis_decoracao                 59.0                       426.0
#
#    product_photos_qty  product_weight_g product_length_cm  product_height_cm  \
# 0                 2.0            1400.0              32.0                6.0
# 1                 2.0            1400.0              32.0                6.0
# 2                 2.0            1400.0              32.0                6.0
# 3                 2.0            1400.0              32.0                6.0
# 4                 2.0            1400.0              32.0                6.0
#
#   product_width_cm order_line_cube_in_ltr  price_round
# 0             28.0                  5.376         40.0
# 1             28.0                  5.376         40.0
# 2             28.0                  5.376         40.0
# 3             28.0                 10.752         40.0
# 4             28.0                  5.376         40.0
#
# [5 rows x 31 columns]

# %%
df_orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102425 entries, 0 to 102424
# Data columns (total 31 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Unnamed: 0                     102425 non-null  int64
#  1   order_id                       102425 non-null  object
#  2   customer_id                    102425 non-null  object
#  3   order_status                   102425 non-null  object
#  4   order_purchase_timestamp       102425 non-null  object
#  5   order_approved_at              102425 non-null  object
#  6   order_delivered_carrier_date   102425 non-null  object
#  7   order_delivered_customer_date  102422 non-null  object
#  8   order_estimated_delivery_date  102425 non-null  object
#  9   order_time                     102425 non-null  object
#  10  delivery_time                  102425 non-null  object
#  11  date_ordinal                   102425 non-null  int64
#  12  shipping_time_delta            102422 non-null  float64
#  13  shipping_duration              102422 non-null  float64
#  14  estimated_duration             102425 non-null  int64
#  15  product_id                     102425 non-null  object
#  16  qty                            102425 non-null  int64
#  17  seller_id                      102425 non-null  object
#  18  shipping_limit_date            102425 non-null  object
#  19  price                          102425 non-null  float64
#  20  freight_value                  102425 non-null  float64
#  21  product_category_name          100965 non-null  object
#  22  product_name_lenght            100965 non-null  float64
#  23  product_description_lenght     100965 non-null  float64
#  24  product_photos_qty             100965 non-null  float64
#  25  product_weight_g               102425 non-null  float64
#  26  product_length_cm              102425 non-null  float64
#  27  product_height_cm              102425 non-null  float64
#  28  product_width_cm               102425 non-null  float64
#  29  order_line_cube_in_ltr         102425 non-null  float64
#  30  price_round                    102425 non-null  float64
# dtypes: float64(13), int64(4), object(14)
# memory usage: 24.2+ MB

# %% [markdown]
# This is a cleaned data table from previous analysis. All missing values are added, all duplicated entries are removed and order lines were consolidated. We only need to format the date fields into datetime format.

# %%
oa.convert_to_dt(df_orders, [
    'order_purchase_timestamp',
    'order_approved_at',
    'order_delivered_carrier_date',
    'order_delivered_customer_date',
    'order_estimated_delivery_date'
    ])

# %%
df_orders.drop(['Unnamed: 0'], axis=1, inplace=True)

# %% [markdown]
# ### Gepgraphic data

# %%
df_geolocation = pd.read_csv('archive/olist_geolocation_dataset.csv')

# %%
df_geolocation.head()
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %%
df_geolocation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000163 entries, 0 to 1000162
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   geolocation_zip_code_prefix  1000163 non-null  int64
#  1   geolocation_lat              1000163 non-null  float64
#  2   geolocation_lng              1000163 non-null  float64
#  3   geolocation_city             1000163 non-null  object
#  4   geolocation_state            1000163 non-null  object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 38.2+ MB

# %%
df_geolocation['geolocation_zip_code_prefix'].value_counts()
# Out:
# geolocation_zip_code_prefix
# 24220    1146
# 24230    1102
# 38400     965
# 35500     907
# 11680     879
#          ...
# 71750       1
# 71742       1
# 26475       1
# 26357       1
# 29826       1
# Name: count, Length: 19015, dtype: int64

# %% [markdown]
# The zip code prefix's are not unique. That means we can not assign look up one distict coordinate for a customer but need to apply an aggregate function. I will use the mean for longitude and latitude. In that way a coordinate is in the middle of the neighbohood with this zip code. The downside is that for visualizations where will be overlapping dots on the with the upper most being the one which is visible. This will be solve this with aggregate functions.

# %% [markdown]
# ---
# ## <a class="anchor" id="eda">II. Exploratory Data Analysis</a>
# The focus is on getting an understanding about the customers buying habits and their locations.

# %%
n_customers = df_customer['customer_unique_id'].nunique()
print('Unique customers: {}'.format(n_customers))
n_cities = df_customer['customer_city'].nunique()
print('Unique cities: {}'.format(n_cities))
# Out:
# Unique customers: 96096
# Unique cities: 4119

# %% [markdown]
# Where are the customers from?

# %%
# City disctribution
df_customer['customer_city'].value_counts().sort_values(ascending=False)
# Out:
# customer_city
# sao paulo            15540
# rio de janeiro        6882
# belo horizonte        2773
# brasilia              2131
# curitiba              1521
#                      ...
# palmares paulista        1
# pires ferreira           1
# vicente dutra            1
# alagoa nova              1
# eugenio de castro        1
# Name: count, Length: 4119, dtype: int64

# %%
(
    df_customer['customer_city']
    .value_counts()
    .sort_values(ascending=False)
    .head(50)
    .plot(kind='bar', figsize=(15, 5))
)

plt.title('Top 50 customer cities')
plt.ylabel('Count of customers');

# %% [markdown]
# The customers come from 4119 different cities, whith Sao Paulo as the city where most of the customers live.

# %%
# How many states are the customers from?
df_customer['customer_state'].nunique()
# Out:
# 27

# %%
# States disctribution
(
    df_customer['customer_state']
    .value_counts()
    .sort_values(ascending=False)
    .plot(kind='bar', figsize=(15, 5))
)

plt.title('Customer states')
plt.ylabel('Count of customers');

# %% [markdown]
# The customers come from 27 different states  whith Sao Paulo as the state where most of the customers live.

# %%
# How many zip codes?
df_customer['customer_zip_code_prefix'].nunique()
# Out:
# 14994

# %%
# Top 50 zip codes
(
    df_customer['customer_zip_code_prefix']
    .value_counts()
    .sort_values(ascending=False)
    .head(50)
    .plot(kind='bar', figsize=(15, 5))
    )

plt.title('Top 50 zip codes')
plt.ylabel('Count of customers');

# %% [markdown]
# When did new customers placed their first order?

# %%
df_orders.head()
# Out:
#                            order_id                       customer_id  \
# 0  2e7a8482f6fb09756ca50c10d7bfc047  08c5351a6aca1c1589a38f244edeee9d
# 1  35d3a51724a47ef1d0b89911e39cc4ff  27ab53f26192510ff85872aeb3759dcc
# 2  c4f710df20f7d1500da1aef81a993f65  4b671f05b6eb9dc1d2c1bae9c8c78536
# 3  81e5043198a44ddeb226002ff55d8ad4  ddd15ef77c83eea8c534d2896173a927
# 4  03b218d39c422c250f389120c531b61f  db857a86c685a6a3a02a705961ec1ff1
#
#   order_status order_purchase_timestamp order_approved_at  \
# 0      shipped               2016-09-04        2016-10-07
# 1    delivered               2016-10-04        2016-10-05
# 2    delivered               2016-10-10        2016-10-10
# 3    delivered               2017-01-09        2017-01-09
# 4    delivered               2017-01-14        2017-01-14
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0                   2016-10-18                           NaT
# 1                   2016-10-14                    2016-10-26
# 2                   2016-10-18                    2016-10-26
# 3                   2017-01-09                    2017-02-24
# 4                   2017-01-16                    2017-01-18
#
#   order_estimated_delivery_date order_time delivery_time  ...  \
# 0                    2016-10-20   21:15:19      13:14:51  ...
# 1                    2016-12-20   14:23:50      02:44:30  ...
# 2                    2016-12-14   15:50:01      15:53:51  ...
# 3                    2017-02-24   00:37:18      09:10:53  ...
# 4                    2017-03-01   14:20:01      09:23:45  ...
#
#    product_category_name  product_name_lenght  product_description_lenght  \
# 0       moveis_decoracao                 59.0                       426.0
# 1       moveis_decoracao                 59.0                       426.0
# 2       moveis_decoracao                 59.0                       426.0
# 3       moveis_decoracao                 59.0                       426.0
# 4       moveis_decoracao                 59.0                       426.0
#
#    product_photos_qty product_weight_g  product_length_cm product_height_cm  \
# 0                 2.0           1400.0               32.0               6.0
# 1                 2.0           1400.0               32.0               6.0
# 2                 2.0           1400.0               32.0               6.0
# 3                 2.0           1400.0               32.0               6.0
# 4                 2.0           1400.0               32.0               6.0
#
#   product_width_cm  order_line_cube_in_ltr  price_round
# 0             28.0                   5.376         40.0
# 1             28.0                   5.376         40.0
# 2             28.0                   5.376         40.0
# 3             28.0                  10.752         40.0
# 4             28.0                   5.376         40.0
#
# [5 rows x 30 columns]

# %%
df_customer_dly = df_orders.groupby(
    'customer_id',
    as_index=False).agg({
        'order_purchase_timestamp': 'min'
        })

# %%
df_customer_dly.groupby('order_purchase_timestamp').count().cumsum().plot(figsize=(15,5))
plt.title('Customers cumulative')
plt.xlabel('Timeline')
plt.ylabel('Customer count cumulative');

# %%
# New customers count by day
ax = df_customer_dly.groupby('order_purchase_timestamp').count().plot(kind='bar', figsize=(15,5))
# set monthly locator
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=1))
# set font and rotation for date tick labels
plt.gcf().autofmt_xdate()
plt.title('Customers cumulative')
plt.xlabel('Timeline')
plt.ylabel('Customer count');

# %% [markdown]
# ## Conclusion
#
# - Customer come from 4119 cities and 27 states
# - Most of the customers live in Sao Paulo by a factor of 2 to the second ranked city, Rio de Janeiro
# - Many new cutomers appeared on Black Friday. It is interesting to see that the impact is not very pronounced when looking at the cumulative customer count for the total time span.
# - Overall, the increase of customers has an upward trend. The trendline is slightly exponential, which means that the growth is accelerating slowly.

# %% [markdown]
# ---
# ## <a class="anchor" id="segmentation">III. Customer Segmentation</a>
# The segmentation will classify customers based on their bying frequency, amount of purchases and money spent.
#
# Question to answer:
# - How are customers segmented according time of purchase, purchase amount and number of orders?

# %%
# Create a work copy
df = df_orders[[
    'customer_id',
    'order_id',
    'order_status',
    'order_purchase_timestamp',
    'product_id',
    'qty',
    'price',
    'product_category_name'
    ]].copy()

# %% [markdown]
# We only are interested in customers which completed the interaction (`order_status` = "delivered").

# %%
df['order_status'].value_counts()
# Out:
# order_status
# delivered      100196
# shipped          1127
# canceled          465
# invoiced          322
# processing        306
# unavailable         7
# approved            2
# Name: count, dtype: int64

# %%
df = df[df['order_status']=='delivered']

# %% [markdown]
# We will pretend that the last day in the dataset represents the current day. Based on this, we calculate the number of days between the purchase and "Today"

# %%
# Setting reference day
df['today'] = df['order_purchase_timestamp'].max()
# Date deltas
df['recency'] = df['today'] - df['order_purchase_timestamp']

# %%
# Need to get the total price for an order line
df['total_price'] = df['qty'] * df['price']

# %%
# Grouping by customer and order (same order_id = same day); This will be the data frame which contains all valid costomers and how they are segmented
df_segmented_customers = df.groupby([
    'customer_id',
    'order_id'
    ], as_index=False).agg({
        'order_purchase_timestamp': 'first',
        'qty': 'sum',
        'total_price': 'sum',
        'today': 'first',
        'recency': 'first'
        })

# %%
df_segmented_customers['recency'].unique()
# Out:
# array([datetime.timedelta(days=288), datetime.timedelta(days=409),
#        datetime.timedelta(days=547), datetime.timedelta(days=378),
#        datetime.timedelta(days=149), datetime.timedelta(days=504),
#        datetime.timedelta(days=180), datetime.timedelta(days=254),
#        datetime.timedelta(days=346), datetime.timedelta(days=18),
#        datetime.timedelta(days=70), datetime.timedelta(days=532),
#        datetime.timedelta(days=204), datetime.timedelta(days=362),
#        datetime.timedelta(days=488), datetime.timedelta(days=322),
#        datetime.timedelta(days=496), datetime.timedelta(days=292),
#        datetime.timedelta(days=136), datetime.timedelta(days=505),
#        datetime.timedelta(days=139), datetime.timedelta(days=227),
#        datetime.timedelta(days=91), datetime.timedelta(days=454),
#        datetime.timedelta(days=334), datetime.timedelta(days=177),
#        datetime.timedelta(days=233), datetime.timedelta(days=114),
#        datetime.timedelta(days=184), datetime.timedelta(days=472),
#        datetime.timedelta(days=79), datetime.timedelta(days=394),
#        datetime.timedelta(days=179), datetime.timedelta(days=59),
#        datetime.timedelta(days=337), datetime.timedelta(days=176),
#        datetime.timedelta(days=224), datetime.timedelta(days=144),
#        datetime.timedelta(days=24), datetime.timedelta(days=112),
#        datetime.timedelta(days=216), datetime.timedelta(days=568),
#        datetime.timedelta(days=109), datetime.timedelta(days=219),
#        datetime.timedelta(days=231), datetime.timedelta(days=16),
#        datetime.timedelta(days=9), datetime.timedelta(days=325),
#        datetime.timedelta(days=38), datetime.timedelta(days=278),
#        datetime.timedelta(days=206), datetime.timedelta(days=116),
#        datetime.timedelta(days=100), datetime.timedelta(days=283),
#        datetime.timedelta(days=84), datetime.timedelta(days=210),
#        datetime.timedelta(days=71), datetime.timedelta(days=314),
#        datetime.timedelta(days=440), datetime.timedelta(days=276),
#        datetime.timedelta(days=156), datetime.timedelta(days=279),
#        datetime.timedelta(days=293), datetime.timedelta(days=52),
#        datetime.timedelta(days=218), datetime.timedelta(days=546),
#        datetime.timedelta(days=303), datetime.timedelta(days=457),
#        datetime.timedelta(days=145), datetime.timedelta(days=317),
#        datetime.timedelta(days=143), datetime.timedelta(days=220),
#        datetime.timedelta(days=182), datetime.timedelta(days=230),
#        datetime.timedelta(days=137), datetime.timedelta(days=175),
#        datetime.timedelta(days=274), datetime.timedelta(days=132),
#        datetime.timedelta(days=209), datetime.timedelta(days=444),
#        datetime.timedelta(days=513), datetime.timedelta(days=196),
#        datetime.timedelta(days=63), datetime.timedelta(days=580),
#        datetime.timedelta(days=479), datetime.timedelta(days=172),
#        datetime.timedelta(days=259), datetime.timedelta(days=506),
#        datetime.timedelta(days=287), datetime.timedelta(days=1),
#        datetime.timedelta(days=65), datetime.timedelta(days=60),
#        datetime.timedelta(days=694), datetime.timedelta(days=214),
#        datetime.timedelta(days=229), datetime.timedelta(days=366),
#        datetime.timedelta(days=133), datetime.timedelta(days=411),
#        datetime.timedelta(days=86), datetime.timedelta(days=120),
#        datetime.timedelta(days=110), datetime.timedelta(days=190),
#        datetime.timedelta(days=388), datetime.timedelta(days=414),
#        datetime.timedelta(days=37), datetime.timedelta(days=576),
#        datetime.timedelta(days=418), datetime.timedelta(days=386),
#        datetime.timedelta(days=140), datetime.timedelta(days=516),
#        datetime.timedelta(days=369), datetime.timedelta(days=416),
#        datetime.timedelta(days=348), datetime.timedelta(days=207),
#        datetime.timedelta(days=195), datetime.timedelta(days=12),
#        datetime.timedelta(days=153), datetime.timedelta(days=566),
#        datetime.timedelta(days=474), datetime.timedelta(days=169),
#        datetime.timedelta(days=562), datetime.timedelta(days=236),
#        datetime.timedelta(days=89), datetime.timedelta(days=69),
#        datetime.timedelta(days=158), datetime.timedelta(days=19),
#        datetime.timedelta(days=85), datetime.timedelta(days=188),
#        datetime.timedelta(days=39), datetime.timedelta(days=90),
#        datetime.timedelta(days=151), datetime.timedelta(days=280),
#        datetime.timedelta(days=115), datetime.timedelta(days=30),
#        datetime.timedelta(days=467), datetime.timedelta(days=250),
#        datetime.timedelta(days=41), datetime.timedelta(days=456),
#        datetime.timedelta(days=80), datetime.timedelta(days=289),
#        datetime.timedelta(days=559), datetime.timedelta(days=445),
#        datetime.timedelta(days=463), datetime.timedelta(days=291),
#        datetime.timedelta(days=168), datetime.timedelta(days=368),
#        datetime.timedelta(days=72), datetime.timedelta(days=53),
#        datetime.timedelta(days=239), datetime.timedelta(days=330),
#        datetime.timedelta(days=242), datetime.timedelta(days=406),
#        datetime.timedelta(days=351), datetime.timedelta(days=235),
#        datetime.timedelta(days=499), datetime.timedelta(days=8),
#        datetime.timedelta(days=534), datetime.timedelta(days=113),
#        datetime.timedelta(days=316), datetime.timedelta(days=166),
#        datetime.timedelta(days=585), datetime.timedelta(days=161),
#        datetime.timedelta(days=192), datetime.timedelta(days=453),
#        datetime.timedelta(days=517), datetime.timedelta(days=307),
#        datetime.timedelta(days=34), datetime.timedelta(days=514),
#        datetime.timedelta(days=473), datetime.timedelta(days=32),
#        datetime.timedelta(days=205), datetime.timedelta(days=373),
#        datetime.timedelta(days=126), datetime.timedelta(days=258),
#        datetime.timedelta(days=535), datetime.timedelta(days=26),
#        datetime.timedelta(days=251), datetime.timedelta(days=263),
#        datetime.timedelta(days=462), datetime.timedelta(days=64),
#        datetime.timedelta(days=311), datetime.timedelta(days=350),
#        datetime.timedelta(days=6), datetime.timedelta(days=228),
#        datetime.timedelta(days=524), datetime.timedelta(days=390),
#        datetime.timedelta(days=197), datetime.timedelta(days=93),
#        datetime.timedelta(days=483), datetime.timedelta(days=352),
#        datetime.timedelta(days=198), datetime.timedelta(days=78),
#        datetime.timedelta(days=308), datetime.timedelta(days=165),
#        datetime.timedelta(days=159), datetime.timedelta(days=423),
#        datetime.timedelta(days=213), datetime.timedelta(days=555),
#        datetime.timedelta(days=162), datetime.timedelta(days=87),
#        datetime.timedelta(days=358), datetime.timedelta(days=43),
#        datetime.timedelta(days=77), datetime.timedelta(days=343),
#        datetime.timedelta(days=306), datetime.timedelta(days=27),
#        datetime.timedelta(days=102), datetime.timedelta(days=260),
#        datetime.timedelta(days=405), datetime.timedelta(days=268),
#        datetime.timedelta(days=490), datetime.timedelta(days=46),
#        datetime.timedelta(days=130), datetime.timedelta(days=393),
#        datetime.timedelta(days=106), datetime.timedelta(days=15),
#        datetime.timedelta(days=398), datetime.timedelta(days=392),
#        datetime.timedelta(days=212), datetime.timedelta(days=49),
#        datetime.timedelta(days=380), datetime.timedelta(days=187),
#        datetime.timedelta(days=345), datetime.timedelta(days=269),
#        datetime.timedelta(days=240), datetime.timedelta(days=476),
#        datetime.timedelta(days=342), datetime.timedelta(days=544),
#        datetime.timedelta(days=131), datetime.timedelta(days=217),
#        datetime.timedelta(days=232), datetime.timedelta(days=572),
#        datetime.timedelta(days=399), datetime.timedelta(days=174),
#        datetime.timedelta(days=573), datetime.timedelta(days=55),
#        datetime.timedelta(days=294), datetime.timedelta(days=173),
#        datetime.timedelta(days=277), datetime.timedelta(days=170),
#        datetime.timedelta(days=122), datetime.timedelta(days=554),
#        datetime.timedelta(days=485), datetime.timedelta(days=481),
#        datetime.timedelta(days=511), datetime.timedelta(days=262),
#        datetime.timedelta(days=57), datetime.timedelta(days=272),
#        datetime.timedelta(days=62), datetime.timedelta(days=211),
#        datetime.timedelta(days=297), datetime.timedelta(days=471),
#        datetime.timedelta(days=420), datetime.timedelta(days=470),
#        datetime.timedelta(days=105), datetime.timedelta(days=152),
#        datetime.timedelta(days=318), datetime.timedelta(days=426),
#        datetime.timedelta(days=367), datetime.timedelta(days=28),
#        datetime.timedelta(days=584), datetime.timedelta(days=142),
#        datetime.timedelta(days=492), datetime.timedelta(days=359),
#        datetime.timedelta(days=155), datetime.timedelta(days=295),
#        datetime.timedelta(days=138), datetime.timedelta(days=123),
#        datetime.timedelta(days=422), datetime.timedelta(days=353),
#        datetime.timedelta(days=181), datetime.timedelta(days=111),
#        datetime.timedelta(days=273), datetime.timedelta(days=478),
#        datetime.timedelta(days=21), datetime.timedelta(days=225),
#        datetime.timedelta(days=536), datetime.timedelta(days=5),
#        datetime.timedelta(days=40), datetime.timedelta(days=396),
#        datetime.timedelta(days=164), datetime.timedelta(days=51),
#        datetime.timedelta(days=302), datetime.timedelta(days=191),
#        datetime.timedelta(days=35), datetime.timedelta(days=13),
#        datetime.timedelta(days=253), datetime.timedelta(days=323),
#        datetime.timedelta(days=103), datetime.timedelta(days=413),
#        datetime.timedelta(days=451), datetime.timedelta(days=446),
#        datetime.timedelta(days=104), datetime.timedelta(days=10),
#        datetime.timedelta(days=477), datetime.timedelta(days=299),
#        datetime.timedelta(days=124), datetime.timedelta(days=285),
#        datetime.timedelta(days=310), datetime.timedelta(days=438),
#        datetime.timedelta(days=234), datetime.timedelta(days=36),
#        datetime.timedelta(days=215), datetime.timedelta(days=501),
#        datetime.timedelta(days=341), datetime.timedelta(days=557),
#        datetime.timedelta(days=244), datetime.timedelta(days=125),
#        datetime.timedelta(days=135), datetime.timedelta(days=428),
#        datetime.timedelta(days=194), datetime.timedelta(days=689),
#        datetime.timedelta(days=447), datetime.timedelta(days=121),
#        datetime.timedelta(days=528), datetime.timedelta(days=74),
#        datetime.timedelta(days=421), datetime.timedelta(days=243),
#        datetime.timedelta(days=3), datetime.timedelta(days=107),
#        datetime.timedelta(days=510), datetime.timedelta(days=376),
#        datetime.timedelta(days=186), datetime.timedelta(days=50),
#        datetime.timedelta(days=148), datetime.timedelta(days=226),
#        datetime.timedelta(days=328), datetime.timedelta(days=347),
#        datetime.timedelta(days=427), datetime.timedelta(days=449),
#        datetime.timedelta(days=281), datetime.timedelta(days=336),
#        datetime.timedelta(days=66), datetime.timedelta(days=360),
#        datetime.timedelta(days=81), datetime.timedelta(days=379),
#        datetime.timedelta(days=430), datetime.timedelta(days=255),
#        datetime.timedelta(days=326), datetime.timedelta(days=382),
#        datetime.timedelta(days=98), datetime.timedelta(days=335),
#        datetime.timedelta(days=265), datetime.timedelta(days=493),
#        datetime.timedelta(days=22), datetime.timedelta(days=531),
#        datetime.timedelta(days=484), datetime.timedelta(days=391),
#        datetime.timedelta(days=525), datetime.timedelta(days=247),
#        datetime.timedelta(days=410), datetime.timedelta(days=163),
#        datetime.timedelta(days=266), datetime.timedelta(days=315),
#        datetime.timedelta(days=171), datetime.timedelta(days=241),
#        datetime.timedelta(days=185), datetime.timedelta(days=571),
#        datetime.timedelta(days=357), datetime.timedelta(days=365),
#        datetime.timedelta(days=183), datetime.timedelta(days=407),
#        datetime.timedelta(days=581), datetime.timedelta(days=500),
#        datetime.timedelta(days=537), datetime.timedelta(days=31),
#        datetime.timedelta(days=160), datetime.timedelta(days=29),
#        datetime.timedelta(days=117), datetime.timedelta(days=75),
#        datetime.timedelta(days=494), datetime.timedelta(days=44),
#        datetime.timedelta(days=275), datetime.timedelta(days=118),
#        datetime.timedelta(days=432), datetime.timedelta(days=56),
#        datetime.timedelta(days=408), datetime.timedelta(days=20),
#        datetime.timedelta(days=387), datetime.timedelta(days=512),
#        datetime.timedelta(days=569), datetime.timedelta(days=298),
#        datetime.timedelta(days=178), datetime.timedelta(days=150),
#        datetime.timedelta(days=108), datetime.timedelta(days=324),
#        datetime.timedelta(days=25), datetime.timedelta(days=296),
#        datetime.timedelta(days=199), datetime.timedelta(days=267),
#        datetime.timedelta(days=42), datetime.timedelta(days=520),
#        datetime.timedelta(days=442), datetime.timedelta(days=14),
#        datetime.timedelta(days=574), datetime.timedelta(days=403),
#        datetime.timedelta(days=519), datetime.timedelta(days=245),
#        datetime.timedelta(days=147), datetime.timedelta(days=469),
#        datetime.timedelta(days=68), datetime.timedelta(days=82),
#        datetime.timedelta(days=468), datetime.timedelta(days=693),
#        datetime.timedelta(days=372), datetime.timedelta(days=435),
#        datetime.timedelta(days=167), datetime.timedelta(days=389),
#        datetime.timedelta(days=284), datetime.timedelta(days=300),
#        datetime.timedelta(days=17), datetime.timedelta(days=339),
#        datetime.timedelta(days=692), datetime.timedelta(days=349),
#        datetime.timedelta(days=383), datetime.timedelta(days=313),
#        datetime.timedelta(days=290), datetime.timedelta(days=482),
#        datetime.timedelta(days=460), datetime.timedelta(days=154),
#        datetime.timedelta(days=375), datetime.timedelta(days=425),
#        datetime.timedelta(days=257), datetime.timedelta(days=371),
#        datetime.timedelta(days=238), datetime.timedelta(days=338),
#        datetime.timedelta(days=385), datetime.timedelta(days=305),
#        datetime.timedelta(days=146), datetime.timedelta(days=202),
#        datetime.timedelta(days=497), datetime.timedelta(days=549),
#        datetime.timedelta(days=498), datetime.timedelta(days=529),
#        datetime.timedelta(days=67), datetime.timedelta(days=83),
#        datetime.timedelta(days=312), datetime.timedelta(days=329),
#        datetime.timedelta(days=522), datetime.timedelta(days=119),
#        datetime.timedelta(days=541), datetime.timedelta(days=309),
#        datetime.timedelta(days=23), datetime.timedelta(days=461),
#        datetime.timedelta(days=45), datetime.timedelta(days=374),
#        datetime.timedelta(days=530), datetime.timedelta(days=570),
#        datetime.timedelta(days=11), datetime.timedelta(days=127),
#        datetime.timedelta(days=448), datetime.timedelta(days=415),
#        datetime.timedelta(days=587), datetime.timedelta(days=515),
#        datetime.timedelta(days=189), datetime.timedelta(days=282),
#        datetime.timedelta(days=495), datetime.timedelta(days=489),
#        datetime.timedelta(days=550), datetime.timedelta(days=377),
#        datetime.timedelta(days=364), datetime.timedelta(days=203),
#        datetime.timedelta(days=526), datetime.timedelta(days=271),
#        datetime.timedelta(days=249), datetime.timedelta(days=545),
#        datetime.timedelta(days=128), datetime.timedelta(days=134),
#        datetime.timedelta(days=439), datetime.timedelta(days=402),
#        datetime.timedelta(days=412), datetime.timedelta(days=688),
#        datetime.timedelta(days=538), datetime.timedelta(days=575),
#        datetime.timedelta(days=88), datetime.timedelta(days=370),
#        datetime.timedelta(days=552), datetime.timedelta(days=464),
#        datetime.timedelta(days=237), datetime.timedelta(days=221),
#        datetime.timedelta(days=223), datetime.timedelta(days=327),
#        datetime.timedelta(days=455), datetime.timedelta(days=97),
#        datetime.timedelta(days=560), datetime.timedelta(days=58),
#        datetime.timedelta(days=252), datetime.timedelta(days=261),
#        datetime.timedelta(days=141), datetime.timedelta(days=193),
#        datetime.timedelta(days=256), datetime.timedelta(days=486),
#        datetime.timedelta(days=47), datetime.timedelta(days=540),
#        datetime.timedelta(days=578), datetime.timedelta(days=437),
#        datetime.timedelta(days=400), datetime.timedelta(days=441),
#        datetime.timedelta(days=331), datetime.timedelta(days=61),
#        datetime.timedelta(days=286), datetime.timedelta(days=301),
#        datetime.timedelta(days=475), datetime.timedelta(days=404),
#        datetime.timedelta(days=208), datetime.timedelta(days=48),
#        datetime.timedelta(days=200), datetime.timedelta(days=95),
#        datetime.timedelta(days=527), datetime.timedelta(days=417),
#        datetime.timedelta(days=333), datetime.timedelta(days=356),
#        datetime.timedelta(days=129), datetime.timedelta(days=551),
#        datetime.timedelta(days=491), datetime.timedelta(days=7),
#        datetime.timedelta(days=73), datetime.timedelta(days=452),
#        datetime.timedelta(days=101), datetime.timedelta(days=304),
#        datetime.timedelta(days=588), datetime.timedelta(days=401),
#        datetime.timedelta(days=361), datetime.timedelta(days=92),
#        datetime.timedelta(days=340), datetime.timedelta(days=363),
#        datetime.timedelta(days=355), datetime.timedelta(days=518),
#        datetime.timedelta(days=465), datetime.timedelta(days=99),
#        datetime.timedelta(days=384), datetime.timedelta(days=480),
#        datetime.timedelta(days=691), datetime.timedelta(days=523),
#        datetime.timedelta(days=548), datetime.timedelta(days=344),
#        datetime.timedelta(days=397), datetime.timedelta(days=270),
#        datetime.timedelta(days=450), datetime.timedelta(days=246),
#        datetime.timedelta(days=459), datetime.timedelta(days=354),
#        datetime.timedelta(days=76), datetime.timedelta(days=264),
#        datetime.timedelta(days=487), datetime.timedelta(days=332),
#        datetime.timedelta(days=556), datetime.timedelta(days=424),
#        datetime.timedelta(days=96), datetime.timedelta(days=222),
#        datetime.timedelta(days=321), datetime.timedelta(days=443),
#        datetime.timedelta(days=436), datetime.timedelta(days=320),
#        datetime.timedelta(days=509), datetime.timedelta(days=542),
#        datetime.timedelta(days=201), datetime.timedelta(days=33),
#        datetime.timedelta(days=507), datetime.timedelta(days=157),
#        datetime.timedelta(days=502), datetime.timedelta(days=4),
#        datetime.timedelta(days=319), datetime.timedelta(days=395),
#        datetime.timedelta(days=2), datetime.timedelta(days=539),
#        datetime.timedelta(days=458), datetime.timedelta(days=561),
#        datetime.timedelta(days=601), datetime.timedelta(days=690),
#        datetime.timedelta(days=543), datetime.timedelta(days=533),
#        datetime.timedelta(days=564), datetime.timedelta(days=567),
#        datetime.timedelta(days=565), datetime.timedelta(days=429),
#        datetime.timedelta(days=94), datetime.timedelta(days=419),
#        datetime.timedelta(days=508), datetime.timedelta(days=433),
#        datetime.timedelta(days=590), datetime.timedelta(days=558),
#        datetime.timedelta(days=614), datetime.timedelta(days=431),
#        datetime.timedelta(days=553), datetime.timedelta(days=54),
#        datetime.timedelta(days=577), datetime.timedelta(days=597),
#        datetime.timedelta(days=579), datetime.timedelta(days=593),
#        datetime.timedelta(days=248), datetime.timedelta(days=586),
#        datetime.timedelta(days=582), datetime.timedelta(days=503),
#        datetime.timedelta(days=466), datetime.timedelta(days=589),
#        datetime.timedelta(days=434), datetime.timedelta(days=381),
#        datetime.timedelta(0), datetime.timedelta(days=521),
#        datetime.timedelta(days=583), datetime.timedelta(days=563),
#        datetime.timedelta(days=598), datetime.timedelta(days=596),
#        datetime.timedelta(days=599), datetime.timedelta(days=594),
#        datetime.timedelta(days=591), datetime.timedelta(days=592),
#        datetime.timedelta(days=695), datetime.timedelta(days=595),
#        datetime.timedelta(days=600), datetime.timedelta(days=713)],
#       dtype=object)

# %%
df_segmented_customers['recency']= df_segmented_customers['recency'].astype(str)
df_segmented_customers['recency']= df_segmented_customers['recency'].str.replace(r'\s+days.*', '', regex=True)
df_segmented_customers['recency']
# Out:
# 0        288
# 1        409
# 2        547
# 3        378
# 4        149
#         ...
# 96473    165
# 96474    153
# 96475     99
# 96476     77
# 96477    361
# Name: recency, Length: 96478, dtype: object

# %%
indexed = df_segmented_customers.loc[df_segmented_customers['recency']=='1 day, 0:00:00'].index
df_segmented_customers.drop(indexed , inplace=True

# %%
indexed = df_segmented_customers.loc[df_segmented_customers['recency']=='0:00:00'].index
df_segmented_customers.drop(indexed , inplace=True)

# %%
df_segmented_customers['recency']= df_segmented_customers['recency'].astype(int)

# %%
df_segmented_customers = df_segmented_customers\
    .groupby('customer_id', as_index=False)\
    .agg({
        'recency': ['min', 'max', 'count'],
        'total_price': ['sum', 'mean']
        })

# %%
# Simplifying columns
df_segmented_customers.columns = [' '.join(col).strip() for col in df_segmented_customers.columns.values]

# %%
# Renaming columns
df_segmented_customers.rename(columns={
    'recency max': 'days_since_first_order',
    'recency min': 'recency',
    'recency count': 'frequency',
    'total_price sum': 'total_payment',
    'total_price mean': 'avg_payment'
    }, inplace=True)

# %%
# Defining time range conditions for classifying customers
total_time_range = str(df["order_purchase_timestamp"].max() - df["order_purchase_timestamp"].min())
total_time_range
# Out:
# '713 days, 0:00:00'

# %%
# Splitting total time range in 4 time periods
period = int(re.sub(r'\s+days.*', '', total_time_range))/4

# %% [markdown]
# ## Assigning activity clasifications

# %%
# activity classes
class_inactive = df_segmented_customers['recency'] > period * 3
class_cold = (df_segmented_customers['recency'] > period * 2)\
    & (df_segmented_customers['recency'] <= period * 3)
class_hot = (df_segmented_customers['recency'] > period)\
    & (df_segmented_customers['recency'] <= period * 2)
class_active = df_segmented_customers['recency'] <= period

# %%
# Adding activity classes to dataframe
df_segmented_customers.loc[class_inactive, "segment"] = "inactive"
df_segmented_customers.loc[class_cold, "segment"] = "cold"
df_segmented_customers.loc[class_hot, "segment"] = "hot"
df_segmented_customers.loc[class_active, "segment"] = "active"

# %%
# Defining payment range conditions for classifying customers
median_payment = df_segmented_customers['avg_payment'].median()

# %%
# Sub classes
class_inactive_low = df_segmented_customers['segment'] == 'inactive'
class_cold_low = (df_segmented_customers['segment'] == 'cold')\
    & (df_segmented_customers['avg_payment'] < median_payment)
class_cold_high = (df_segmented_customers['segment'] == 'cold')\
    & (df_segmented_customers['avg_payment'] >= median_payment)
class_hot_low = (df_segmented_customers['segment'] == 'hot')\
    & (df_segmented_customers['avg_payment'] < median_payment)
class_hot_high = (df_segmented_customers['segment'] == 'hot')\
    & (df_segmented_customers['avg_payment'] >= median_payment)
class_active_low = (df_segmented_customers['segment'] == 'active')\
    & (df_segmented_customers['avg_payment'] < median_payment)
class_active_high = (df_segmented_customers['segment'] == 'active')\
    & (df_segmented_customers['avg_payment'] >= median_payment)

# %%
# Adding sub classes to dataframe
df_segmented_customers.loc[class_inactive_low, "sub_segment"] = "inactive"
df_segmented_customers.loc[class_cold_low, "sub_segment"] = "cold_low"
df_segmented_customers.loc[class_cold_high, "sub_segment"] = "cold_high"
df_segmented_customers.loc[class_hot_low, "sub_segment"] = "hot_low"
df_segmented_customers.loc[class_hot_high, "sub_segment"] = "hot_high"
df_segmented_customers.loc[class_active_low, "sub_segment"] = "active_low"
df_segmented_customers.loc[class_active_high, "sub_segment"] = "active_high"

# %%
# We can use this color scheme for various visualizations
dict_colors = {
    'inactive': 'midnightblue',
    'cold_low': 'blue',
    'cold_high': 'mediumslateblue',
    'hot_low': 'darkorchid',
    'hot_high': 'magenta',
    'active_low': 'deeppink', 
    'active_high': 'red'
    }

# %%
# Total revenue by sub-segment
oa.plot_waffle_chart(df_segmented_customers, 'total_payment', 'sum', 'Revenue by Sub-Segment')
# Out:
# <Waffle size 800x500 with 1 Axes>

# %%
# Total orders placed by sub-segment
oa.plot_waffle_chart(df_segmented_customers, 'frequency', 'sum', 'Orders by Sub-Segment')
# Out:
# <Waffle size 800x500 with 1 Axes>

# %%
# Number of customers per sub-segment
oa.plot_waffle_chart(df_segmented_customers,'customer_id', 'count', 'Number of customers by Sub-Segment')
# Out:
# <Waffle size 800x500 with 1 Axes>

# %% [markdown]
# ## Conclusion
# **Geographic relationship in view of customer characteristics**
#
# - The strongest class of the 7 generated sub-segments is active customers with high spending, followed by "hot" customers which high spending, which is a good sign for the business.
# - Active customers with high and low spending placed the most orders, followed by "hot" customers.
# - Active customers are also the biggest groups in terms of head count.
# - Inactive customers represent in each chart the smallest proportion.
#
# This segmentation provides a base to develop a strategy how and if to target customers.

# %% [markdown]
# ---
# ## <a class="anchor" id="geosegmentation">IV. Geodemographic Segmentation</a>
# In this classification the customers are geographically visualized based on quantitive comparison of multiple characteristics.
#
# Question to answer:
# - Is there a geolographical correlation to specific characteristics?

# %%
# Making dictionaries to mapp zip code prefix and coordinates to the customers
dict_cust_zip = df_customer.set_index('customer_id').to_dict()['customer_zip_code_prefix']
dict_lat = df_geolocation.set_index('geolocation_zip_code_prefix').to_dict()['geolocation_lat']
dict_lng = df_geolocation.set_index('geolocation_zip_code_prefix').to_dict()['geolocation_lng']

# %%
# Adding zip code to df
df_segmented_customers['geolocation_zip_code_prefix']\
    = df_segmented_customers['customer_id'].map(dict_cust_zip)

# %%
# Adding coordinates and color code to the dataframe
df_segmented_customers['geolocation_lat']\
    = df_segmented_customers['geolocation_zip_code_prefix'].map(dict_lat)
df_segmented_customers['geolocation_lng']\
    = df_segmented_customers['geolocation_zip_code_prefix'].map(dict_lng)
df_segmented_customers['color']\
    = df_segmented_customers['sub_segment'].map(dict_colors)

# %% [markdown]
# ## Geodemographic map of sub-segments
# Evaluation how our customer segmentation is located on the map. Because the zip code prefix is not individually assigned to a specific customer and is not the detailed zip code I need to work with: 1) coordinates which are ageraged for a specific neighborhooe and 2) aggregate all metrics for the coordinates (a coordinate can have many customers with different values).

# %%
# Because the coordinates of the customers are not unique (explanation in the data import) I need to extract the most common cutomer call (color)
# Sample size set to reduce file size; can be removed to see full picture
sample_subsegments = df_segmented_customers.groupby(
    'geolocation_zip_code_prefix',
    as_index=False
    ).agg({
        'geolocation_lat': 'first',
        'geolocation_lng': 'first',
        'color': lambda x:x.value_counts().index[0]
        }).sample(n=200)

# %%
oa.plot_map(sample_subsegments, 'Geological distribution of customer sub-segments',0, 0, 'n', 2, True)
# Out:
# <div>                            <div id="627c955b-8dbe-4d53-be5e-677d1800a84e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("627c955b-8dbe-4d53-be5e-677d1800a84e")) {                    Plotly.newPlot(                        "627c955b-8dbe-4d53-be5e-677d1800a84e",                        [{"lat":[-23.29560317485143,-22.950850460374124,-23.664451809048412,-7.497497634293608,-22.930686505224596,-25.53272939272321,-23.518553783513184,-21.711479175688137,-22.49662441456981,-6.206925327990684,-23.351305499999995,-19.877003517629376,-23.60441430697094,-22.878726994180354,-20.67324585848713,-23.57824510451045,-23.48715090229693,-22.82740732925937,-23.010010522621027,-15.76528459695353,-30.044104124617697,-2.925278965523711,null,null,-23.490617505282756,-19.002214302635803,-29.15139404741357,-18.37239454785955,-21.74107222499438,-20.39398990556411,-21.031326603149456,-25.358787581257257,-23.51484594309681,-15.753189944255825,-23.63183739133823,-15.853908943255044,-22.72932973377276,-27.073586999999947,-23.51858789271629,-6.985635101513383,-3.732303122395995,-22.749719196779964,-22.845009510675805,-15.49434999999994,-23.39093286968532,-23.55076547515727,-23.454878479600666,-13.363458860606746,-27.457135549027814,-23.58116390230251,-23.264842372556974,-23.641245408275115,-15.913198420770463,-22.91630667115865,-19.958828686724317,-23.42547128877304,-19.25916247866048,-6.755665337401157,-12.692833309215224,-29.46157289736813,-23.660101665560592,-15.788459536211027,-27.07925947667201,-23.58754476602805,-22.445440515507396,-15.854445547796969,-23.57086177269314,-27.585918503462448,-24.739374763471847,-23.61028679156327,-8.32996193458892,-19.871862809885133,-7.732584221130208,-22.784303999999945,-3.71266800974117,-23.364283562344667,-18.66019654833491,-23.932212328173765,-5.081489190768237,-22.97444173633788,-8.10190511170847,-9.420372209766985,-3.037722181516526,-27.00754271218764,-22.37463249804501,-23.62796148183387,-23.68827403358529,-23.624294647238727,-19.79038321523396,-8.51681994399804,-11.958239999999932,-12.950638357489847,-16.68978338463076,-22.9613114188746,-8.41221770164879,-23.669194493219333,-23.54324259737804,-22.823354283109158,-22.89352897486686,-22.86813234442272,-5.008241895548203,-23.618112463788968,-19.75726981567815,-23.400160516988425,-5.766012628368606,-19.7280286583682,-23.67328288343239,-3.073580053277962,-18.53918188357027,-25.54296596117622,-22.81870611020593,-15.611889901126798,-23.532769174562965,-15.841159228299446,-13.408873094632735,-23.52629183458364,-31.32518527136253,-2.607682898713797,-23.680939368861427,-17.466189239170824,-21.94794943546702,-15.798334500000005,-21.16918303862985,-23.5277486611172,-12.930095509839576,-27.256940467797072,-10.441720286106696,-23.657469641782328,-13.347200232824898,-26.76304945520739,-7.9111128963843775,-8.088002789806648,-23.260621201771624,-28.38893187660049,-20.29499245682819,-22.705038670089447,-1.2825392309677002,-24.020064597005,-12.729107494688892,-23.48463990813089,-24.976764000000003,-12.94586167665742,-21.12121817060188,-23.559786534277787,-23.599630877073803,-12.125752760711912,-22.867186253840657,-22.924492407438397,-19.957474572566294,-19.782777074832342,-13.11856971953075,-23.41456240882338,-26.29257066388715,-24.141176319106357,-22.79660298594252,-26.781657403258844,-1.3389850885508945,-32.56113582565404,-22.961199372756568,-15.83922292662938,-18.939731395233377,-5.013609119536064,-15.296389233549068,-20.388940030538503,-23.63242610046745,-12.999654206242706,-24.03037268948743,-25.21336246690558,-23.602725135726203,-23.55951039494492,-22.158845019693143,-22.543459166801338,-23.19560872217096,-28.6754870813608,-23.049162489671204,null,-13.012793580471804,-22.67042456618965,-22.81343462038492,-27.944944534140177,-8.14062708 ...

# %% [markdown]
# As expected, the customers are concentrated around the big cities in the east of the country. On the first view, there is not a clear concentration of sub-segments in specific areas.

# %% [markdown]
# ## Areas by cumulative revenue

# %%
sample_renenue = df_segmented_customers.groupby(
    'geolocation_zip_code_prefix',
    as_index=False
    ).agg({
        'total_payment': 'sum',
        'geolocation_lat': 'first',
        'geolocation_lng': 'first'
        }).sample(n=200)

# %%
# Distribution of total revenue
plt.figure(figsize=(12, 5))
sns.distplot(sample_renenue['total_payment'], bins=300);
plt.title('Distribution total revenue per zip code prefix')
plt.xlabel('Total revenue');
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_9644\485839478.py:3: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning:
#
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.

# %% [markdown]
# A big majority of neighborhoods is on the low end of the distribution when looking at the summarized revenue. This can have different reasons: 1) Small group size, 2) Low purchase values, 3) a combination of 1 and 2

# %%
oa.plot_map(sample_renenue, 'Cumulative revenue',100 , 3000, 'total_payment', 2, False)
# Out:
# <div>                            <div id="7045b195-a9f5-4a39-be57-e9ea09d4b251" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7045b195-a9f5-4a39-be57-e9ea09d4b251")) {                    Plotly.newPlot(                        "7045b195-a9f5-4a39-be57-e9ea09d4b251",                        [{"lat":[-20.13184344955177,-23.504335656108086,-24.195329632814914,-22.31580483001883,-22.309450228980285,-19.85157837108313,-7.25733866405046,-23.642148740492814,-15.625527576466194,-23.4078863857122,-27.64441001566128,-23.575805161261425,-12.61737622366928,-22.77585937307125,-23.60064149486411,-23.535031725229388,-7.998677340816043,-29.21105556299624,-23.679725448785323,-27.18307007314713,-5.643356211079868,-23.287356000000003,-26.905441672025844,-19.77275727200066,-15.907826499260002,-23.550749808906605,-29.15722361670253,-5.031912370057341,-23.534649920059792,-2.578486500000004,-27.243208098295906,-23.45313627254892,-10.295836306922215,-21.820885759012512,-4.490700040153764,-5.753144085204006,-23.67246813765943,-23.55825039439666,-6.965758643985117,-7.898597503599655,-22.896609118789318,-8.03614354119822,-23.51349268220902,-7.255648909279019,-30.25980385173452,-19.924019225085143,-23.680929489035723,-27.58671773189448,-23.47547598029316,-8.134601368742848,-26.82145663835193,-22.31947056174626,-25.413359301690825,-22.70684622965929,-21.135007561198,-23.531426646089145,-21.490166837975345,-20.34005384380753,-25.443859285042404,-23.631500294477465,-23.464959443793653,-6.55542585890392,-28.02879522983105,-12.97291544613586,-23.394234687460933,-12.612234617119384,-23.037266459189134,-22.588623922009347,-23.522071997230043,-22.752400086040733,-21.707270373057334,-23.435608107132552,-23.50414306650768,-2.423943306446032,-22.43225433737873,-12.149865064169871,-29.53161001583168,-20.185681901906683,-23.560307570633064,-23.557167633183905,-23.60281321442631,-3.908461126392541,-3.742219163376388,-26.81878410518652,-9.315972565792991,-21.19496550457901,-21.61000575682632,-10.499718836885348,-12.98610920037282,-23.545402492353947,-23.465667949766264,-19.44455181263568,-29.860846174052675,-23.65594170690752,-23.25220929312685,-23.579327515119207,-22.81128931779098,-23.769335306445,-28.78932208585175,-22.97462137024641,null,-29.847222865166906,-23.56827643603204,-17.998586824666884,-23.57005730474925,-22.07088568682188,-23.537703949766275,-12.818776500000002,-23.55467350531036,-7.013184968409067,-22.950850460374124,-23.517934134889483,-21.75718243352188,-23.56578231930104,-29.60807886889687,-23.59330543658029,-23.580848168474777,-12.928281557181926,-25.88090292257697,-22.47824730820197,-15.649366500000005,-22.849567301182145,-15.808023418553114,-22.884016129454384,-12.244084653581137,-26.91469243159541,-26.159085806199755,-15.811510286597086,-26.14388352442686,-24.657263936898214,-26.90714870858024,-20.53539806126602,-9.41452499999997,-19.004322733803647,-12.263934080776172,-3.077714210658426,-20.019743595101048,-15.530418274722768,-26.23563275775529,-23.50709816625308,-23.549530033585302,-23.03761869345971,-23.52925705744708,-11.845530533041774,-23.58648173850752,-19.14771986635469,-22.53530325476392,-29.88422467705147,-21.674265221294853,-23.62857983119472,-22.12315688188973,-12.38479739905688,-23.50698677586167,-3.7110186783462633,-22.877720665725526,-23.577010722170964,-17.348317628337337,-3.752884720557982,-16.629821443736798,-23.57726377697909,-20.79759127731009,-23.47454934693289,-22.802545553838332,-27.000196811578707,-26.62034623850441,-20.60313125411237,-22.87396114793121,-16.61089060048986,-23.469038932726072,-28.65993634989169,-23.21510979233531,-23.616375852067065,-23.54723481258382,-11.847179068625543,-22.859388170464968,-29.675931853872456,-28.30763557282309,-9.673038265122305,-17.311654999999945,-22.7 ...

# %% [markdown]
# The chart shows that there is some clustering between higher revenue and lower revenue areas, especially if setting the lower bound threshold higher. In neighborhoods of "Campinas" mostly higher total values while in the suburbs "Vila Amelia", "Brasilandia" and "Limao District" mostly lower values dominate. Rio de Janeiro, especially around the waterfront is mostly blue, while the north-western suburbs are mainly red.
#
# We need to be careful with the interpretation here:
# - As seen in the EDA section, some zip codes have more customers assigned, so a high total value can be an effect of a big group size
#
# As a refresher, a box chart to display the statistical distribution of the group sizes:

# %%
plt.figure(figsize=(15, 2))
sns.boxplot(data=df_segmented_customers.groupby('geolocation_zip_code_prefix').agg({'total_payment': 'count'}), orient='h')

plt.xlabel('Group size')
plt.title('Zip code group sizes');

# %% [markdown]
# The distribution of the group sizes is very similar to what we see in the distribution of the total revenue. That means, that neighborhoode with higher revenue have that higher value most likely because of a biger amount of customers within this zip code prefix.
#
# We can do a normalization by dividing the total revenue by the numbers of customers to get a tota revenue per customer for a specific zip code, or in other words: Take the average of the total_payments.

# %% [markdown]
# ## Distribution of average purchase value
# The average purchase price spending is independent of the group size and will tell a bit more about spending behavior of individuals in an area.

# %%
# Sample size set to reduce file size; can be removed to see full picture
sample_avg_spend = df_segmented_customers.groupby(
    'geolocation_zip_code_prefix',
    as_index=False
    ).agg({
        'total_payment': 'mean',
        'geolocation_lat': 'first',
        'geolocation_lng': 'first'
        }).sample(n=500)

# %%
# Distribution of average purchase value
plt.figure(figsize=(15, 5))
sns.distplot(sample_avg_spend['total_payment'], bins=300);
plt.title('Distribution average purchase value per zip code prefix')
plt.xlabel('Average purchase value');
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_9644\3502017689.py:3: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning:
#
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.

# %% [markdown]
# Above shows the average purchase value distribution, averaged over zip codes. It shows a right-skewed curve. The majority of the purchase values is in the range of 100-120. This seems also to be in line with the general product cost distribution (reference EDA analysis in "Olist Business Trend Analysis").

# %%
oa.plot_map(sample_avg_spend, 'Average prchase value', 50, 280, 'total_payment', 3, False)
# Out:
# <div>                            <div id="b1f9afe0-2f50-4434-b5b1-ead569e3c843" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b1f9afe0-2f50-4434-b5b1-ead569e3c843")) {                    Plotly.newPlot(                        "b1f9afe0-2f50-4434-b5b1-ead569e3c843",                        [{"lat":[-23.61248674132954,-3.740195986121537,-24.05343429225576,-3.102917479600662,-22.46444353621103,-22.67042456618965,-23.442417744647766,-23.730789770957653,-17.399366218740273,-17.357162303098534,-22.95729250375091,-7.700312999999944,-3.5099853385040247,-12.59934721399352,-17.36474266653958,-3.6824580000000022,-26.771074823879555,-7.632756530659956,-21.76806150362966,-24.38208817865001,-23.66059053649949,-23.96906960144808,-21.93838990809384,-29.69353447664457,-23.701383575913173,-26.433214497346025,-28.628909949819374,-15.85508925674532,-23.517487477378967,-23.63258918956661,-14.104391154284496,-8.089547280598994,-23.01138449999999,-26.287410478215683,-23.31418253788448,-23.57276405190717,-23.76241764723873,-12.919626099239265,-16.441187521784308,-23.44565748972094,-19.79944643158864,-23.50571068587252,-23.625763072162272,-8.609681952923989,-23.457355323619367,-23.50238730030584,-12.676734631407086,-4.974219364844913,-6.278411999999946,-22.72678318704116,-19.517730133890687,-21.923476776548497,-26.22960755941113,-20.873351107499424,-22.720930316477727,-23.469038932726072,-18.93878864360412,-23.570462478034955,-5.189819484273771,-22.428431140606417,-3.734407674269873,-13.18728297320018,-18.388676238878784,-18.15004149904516,-22.866961499999995,-20.575712514570952,-7.244204223095365,-22.220617652990903,-22.86975933221771,-12.914409453891103,-12.828145348166478,-22.753065968563597,-18.11974205143918,-25.48650811656761,-23.49260899417162,-28.6754870813608,-25.47170543190041,-22.7246412903998,-23.549998129086763,-2.688641815185236,-21.829810268888377,-19.955785787408324,-23.66026129808414,-12.995643656673796,-22.373051232630683,-3.731211460940532,-23.490617505282756,-20.33216084148386,-23.614078966414706,-13.408873094632735,-23.47612408895716,-23.65016643922822,-23.59363985658718,-16.61678464821406,-6.867034427148714,-12.27903441445658,-22.89333964089154,-15.672842259221351,-23.563358947544568,-20.659719059140578,-23.46308679171931,-21.237735478411047,-23.545964084655758,-20.682832359333883,-23.535956535662766,-26.954943688260396,-19.90978381320335,-23.59806501326094,-23.59267441993187,-23.593684945322863,-16.680762540249265,-12.942802351171276,-16.698402630136986,-23.282221754449004,-23.41065158895492,-12.980134445467105,-22.79660298594252,-23.59707512994282,-27.192207202526102,-22.313647683574057,-23.66138519761669,-22.379642895089145,-29.954274744012917,-19.46727219817388,-23.49754265858092,-22.117960735934663,-23.616375852067065,-2.4013009725035435,-23.651273797391653,-22.73456993528054,-22.81128931779098,-9.418625991305202,-12.246333079167243,-9.451709077833714,-10.829283395212002,-6.210464830858739,-23.486924000836712,-15.813700667610266,-23.841987813423977,-24.01368886733222,-9.55866169080362,-23.5055134118818,-27.98811094709092,-10.242191050504964,-26.17374935146228,-23.299001072814956,-20.330338821678254,-19.753393226509814,-22.44336096725142,-22.116610129481515,-22.50752059216748,-13.76117686900649,-15.833236500000002,-25.376872568959623,-24.494737268360755,-23.438256621703506,-25.123813994171613,-13.734665913741887,-22.852401412110584,-15.821203788659988,-18.968042551425533,-23.506772467684097,-16.440095056159034,-23.32879866344013,-27.58778143689201,-6.369528777855012,-26.9072830861819,-6.015192309876995,-22.571208,-21.79245292705022,-23.59236396725141,-22.550440258303052,-30.034441819750047,-2.545502814876797,-9.613217239287312,-22.331759603255836,-23.53065208881069,-22.635020999999945,-23.5 ...

# %% [markdown]
# By adjusting the lower- and uppder band of the color scale it can be seen that there's a general tendency of lower purchase prices in the South of Brazil while higher purchase prices are more existing in the North. The effect is not very pronounced but still visible. A significance test to statistically prove that this difference has sufficient evindence would need to be done in case this will be considered important in the final business case.

# %% [markdown]
# ## First and last order by location
# When did new customers appeared where? When and where were the last orders placed?

# %%
# Sample size set to reduce file size; can be removed to see full picture
sample_latest_purch = df_segmented_customers.groupby(
    'geolocation_zip_code_prefix',
    as_index=False
    ).agg({
        'recency': 'mean',
        'geolocation_lat': 'first',
        'geolocation_lng': 'first'
        }).sample(n=500)

sample_avg_newbies = df_segmented_customers.groupby(
    'geolocation_zip_code_prefix',
    as_index=False
    ).agg({
        'days_since_first_order': 'mean',
        'geolocation_lat': 'first',
        'geolocation_lng': 'first'
        }).sample(n=500)

# %%
plt.figure(figsize=(15, 5))
sns.distplot(sample_latest_purch['recency'], color='red', bins=100)
sns.distplot(sample_avg_newbies['days_since_first_order'], color='blue', bins=100)

plt.title('Recency of first and last order')
plt.xlabel('Days before reference day')
plt.legend(['Days since latest order', 'Days since first order'])
plt.show();
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_9644\2553180083.py:2: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning:
#
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#
# C:\Users\HP\AppData\Local\Temp\ipykernel_9644\2553180083.py:3: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning:
#
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.

# %% [markdown]
# Most of the orders in general were placed in the range of 200-250 days before "day 0" (our reference day = last order in dataset).

# %%
oa.plot_map(sample_avg_newbies, 'First orders',50 ,500 , 'days_since_first_order', 3, False)
# Out:
# <div>                            <div id="96f82c98-a89c-4524-b373-692684b08720" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("96f82c98-a89c-4524-b373-692684b08720")) {                    Plotly.newPlot(                        "96f82c98-a89c-4524-b373-692684b08720",                        [{"lat":[-22.13011408473035,-21.27815530998053,-23.45034565452699,-25.46194461226844,-22.857702754405075,-27.63556827725788,-22.279517283378095,-26.5405973128398,-23.48594527477061,-23.609275218708515,-22.79653950697765,-17.859238740051595,-30.027835423827018,-23.71484185777596,-16.822606829305983,-6.775360058122535,-21.45190457360049,-23.729599414103493,-31.110810019355224,-23.576922503462445,-19.932557293203395,-12.25724952178431,-27.3136999455462,-16.35604606882095,-7.174745999999999,-15.78404999999995,-8.28899315434633,-29.15314898613227,-15.672842259221351,-23.61379817995001,-3.7614415692879537,-23.485746331669443,-26.923516613316806,-23.28561648611075,-25.496172,-23.65197939133824,-22.896191124646357,-23.490403606440065,-28.83169781077924,-22.74002204170808,-19.987084497922528,-7.3736317244814655,-19.836848121431164,-5.805822138898999,-29.94062452257086,-23.487440364418035,-22.09020428833456,-23.2888735434244,-11.342061430005698,-23.538909268942238,-23.01941733218904,-23.502482172081464,-25.533414167638057,-23.01018653231589,-20.50197648024746,-21.052055999999943,-15.89504340984825,-20.488735718016024,-10.936782210853051,-7.586722504070562,-22.69815159582012,-17.433990759993183,-23.71024852589249,-21.719695608595355,-3.761554499999991,-19.95461130336426,-21.87726470208576,-2.90074753973722,-23.68675279152478,-27.697564727559342,-20.351832503563745,-23.2400673388828,-23.309470796915104,-23.287356000000003,-23.553265470420857,-3.504514941264218,-7.35883063110161,-10.71805835414371,-29.37504169601122,-23.592070844125537,-16.25320694037059,-18.73676762655833,-20.30810180727938,-22.918089632358413,-15.72562282431186,-23.589062612816704,-22.90371209448735,-20.20024239439666,-23.521201529520383,-23.52452688121069,-10.739762378763375,-23.6512359287572,-3.734407674269873,-23.72736220846996,-23.592741359426373,-23.99884160163853,2.796386493848668,-24.183391644751083,-22.505122194558258,-19.855028189566603,-23.53909762003007,-22.53600064946043,-10.67826999999994,-16.683424423157,-6.410491758122982,-3.813887999999945,-20.962349999999997,-3.7521218079804894,-25.53722607917125,-23.541836866783967,-6.718340771034258,-23.59697464946043,-23.586401957983067,-23.50583997890818,-8.26643817346644,-23.589083043020366,-24.73090204312466,-8.200520818813768,-23.260621201771624,-23.50594480724965,-23.273406,-28.426988604876847,-23.00603262774081,-20.061346156856047,-15.808582003469702,-15.802939944588518,-19.97026089587052,-23.454414701915848,-15.83163862254023,-7.553377022798068,-23.52923258174156,-16.673465999999944,-22.88868466665711,-23.607228604218363,-8.359011479343248,-22.772061,-23.52823159172489,-22.90481260283338,-22.845009510675805,-15.830932016803072,-23.571018376363245,-18.94441254714852,-27.54667692278727,-29.642915883266635,-16.005949037561773,-22.86408205133024,-7.732584221130208,-10.204852164019975,-23.60011784984708,-7.1985094407354575,null,-21.83871937555729,-29.90798703061639,-21.08995925473888,-25.437696549252777,-15.131121429880526,-23.9449051357262,-23.40199367277395,-23.494215862605653,-23.730789770957653,-23.485479799613355,-8.878810022765263,-3.03950076976601,-16.175002395227942,-23.79927776985284,-29.219801503202635,-23.534672602085628,-23.458204240944088,-25.246186219095467,-23.503246512349254,-22.191886415678447,-32.045662546814015,-23.47998822814357,-23.47004147509032,-12.979818850372276,-23.462333497085808,-14.95546518861614,-9.565427772973544,-17.802884735206145,-21.71958209908248,-23.5827598413 ...

# %% [markdown]
# There is not a specific geographic dependency to see in the visualization.

# %% [markdown]
# ## Conclusion
#
# **Geographic relationship in view of customer characteristics**
#
# - There is not a clear correlation between location and customer sub-segment to observe
# - Some level of clustering in view of higher- and lower total reveny can be seen. This might for a big part be the effect of the group sizes.
# - There seem to be a slightly higher spending in the north of Brazil. A statistical test to validate this statement would need to be performed before basing any decisions on this.

# %% [markdown]
# ---
# ## Exporting generated dataframes for downstream projects

# %%
#Export dataframe for downstream analysis
df_segmented_customers.to_csv('archive/segmented_customers.csv')
